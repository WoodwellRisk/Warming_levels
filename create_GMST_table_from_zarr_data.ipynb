# %% [markdown]
# # Create a table of global mean surface air temperature (GMST) for each CMIP6 model, ensemble member, scenario, and year

# %%
import numpy as np
import pandas as pd
import xarray as xr
import fsspec

# %%
outdir = '/home/abbylute/alute_bucket/warming_levels/data/gmst_tables/'

# Open the CMIP6 zarr data catalog 
df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')

# get list of models to use
wr = pd.read_csv('/home/abbylute/alute_bucket/warming_levels/data/model_tables/all_zarr_models.csv')
wr = wr.drop_duplicates()
outfile = outdir + 'CMIP6_GMST_table_all.csv'
scenarios = ['historical','ssp119','ssp126','ssp245','ssp370','ssp434','ssp460','ssp534-over','ssp585'] 
        
mods = wr['model'].tolist()

# %%
# view the table of model/institution/ensemble member combinations to get data for
wr
# Out:
#              model institution     member
# 0         GFDL-CM4   NOAA-GFDL   r1i1p1f1
# 2        GFDL-ESM4   NOAA-GFDL   r1i1p1f1
# 3        GFDL-ESM4   NOAA-GFDL   r3i1p1f1
# 4        GFDL-ESM4   NOAA-GFDL   r2i1p1f1
# 9     IPSL-CM6A-LR        IPSL   r3i1p1f1
# ...            ...         ...        ...
# 1695    NorESM2-LM         NCC   r7i1p1f2
# 1696    NorESM2-LM         NCC   r4i1p1f2
# 1697    NorESM2-LM         NCC   r3i1p1f2
# 1698    NorESM2-LM         NCC   r1i1p1f2
# 1699    NorESM2-LM         NCC  r10i1p1f2
#
# [510 rows x 3 columns]

# %%
# how many unique models are we getting data for?
wr['model'].drop_duplicates().shape
# Out:
# (50,)

# %%
# Create a pandas dataframe to fill in with the GMST data
outdf = pd.DataFrame(columns=['model','member','scenario','year','GMST','1850-1900'])
outdf
# Out:
# Empty DataFrame
# Columns: [model, member, scenario, year, GMST, 1850-1900]
# Index: []

# %%
# function to create spatially weighted means
# adapted from https://docs.xarray.dev/en/stable/examples/area_weighted_temperature.html
def spatial_mean(xx):
    weights = np.cos(np.deg2rad(xx.lat))
    weights.name = "weights"
    xx_weighted = xx.weighted(weights)
    weighted_mean = xx_weighted.mean(("lon", "lat"))
    return weighted_mean

# %%
for m in range(len(mods)):
    print(str(m/len(mods)*100) + '% done')
    wrm = wr.iloc[m]

    # reset base
    base = np.nan
    
    for s in range(len(scenarios)):
        scen = scenarios[s]

        # find the model and scenario in the zarr data

        # see if data is available from zarr
        df_zarr = df.query("table_id == 'Amon' & variable_id == 'tas' & experiment_id == '" + scen + "' & institution_id == '" + wrm.institution + "' & source_id == '" + wrm.model + "' & member_id == '" + wrm.member + "'")
        
        # catch special case where MPI-ESM1-2-HR isn't found. Trying using MPI-M institution instead
        if ((len(df_zarr)==0) & (wrm.model == 'MPI-ESM1-2-HR')):
            df_zarr = df.query("table_id == 'Amon' & variable_id == 'tas' & experiment_id == '" + scen + "' & institution_id == 'MPI-M' & source_id == '" + wrm.model + "' & member_id == '" + wrm.member + "'")

                                 
        if (len(df_zarr)==0): 
            1
            print('not available')
        else:
            # first grab the historical period data
            zstore = df_zarr.zstore.values[0]
            # create a mutable-mapping-style interface to the store
            mapper = fsspec.get_mapper(zstore)
            # open it using xarray and zarr
            zz = xr.open_zarr(mapper, consolidated=True)
            # make sure time is sorted
            zz = zz.sortby('time')
            if scen == 'historical':
                try:
                    zz = zz.sel(time=slice('1850-01-01','2014-12-31'))
                except:
                    zz = zz.sel(time=slice('1850-01-01','2014-12-30')) # for 360 day calendars
            else:
                try:
                    zz = zz.sel(time=slice('2015-01-01','2150-12-31'))
                except:
                    zz = zz.sel(time=slice('2015-01-01','2150-12-30')) # for 360 day calendars
                    
            if zz.time.dtype != '<M8[ns]':
                zz['time'] = zz.indexes['time'].to_datetimeindex()
    
            # calculate annual spatially-averaged temperatures

            # weight months by days in month
            month_length = zz.time.dt.days_in_month
            weights = (month_length.groupby("time.year") / month_length.groupby("time.year").sum())
            # Test that the sum of the weights for each season is 1.0
            np.testing.assert_allclose(weights.groupby("time.year").sum().values, np.ones(int(len(weights)/12))[0:len(weights.groupby("time.year").sum())])
            # Calculate the time-weighted average
            zz['tasann'] = (zz.tas * weights).groupby("time.year").sum(dim="time")

            # make sure that x and y are lon and lat
            try:
                zz = zz.rename({'latitude':'lat','longitude':'lon'})
            except:
                1
                
            # calculate the spatially weighted GMST
            zz = spatial_mean(zz)
            
            if scen=='historical':
                # get base period temperature
                base = zz.tasann.sel(year=slice('1850','1900')).mean('year').values
            
            # Add the GMST data to the output df
            yrs = zz.year.values
            ny = len(yrs)

            data = {'model': [mods[m]]*ny,
                    'member': [wrm.member]*ny,
                    'scenario': [scen]*ny, 
                    'year': yrs, 
                    'GMST': zz.tasann.values,
                    '1850-1900': [base]*ny}

            # Create mini dataframe for this model/scenario
            dfmini = pd.DataFrame(data, columns=['model','member','scenario','year','GMST','1850-1900'])
            
            # append this data for this model/scenario to the master GMST table
            outdf = pd.concat([outdf,dfmini])
# Out:
# 0.0% done
# /home/abbylute/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
# not available
# not available
# /home/abbylute/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
# not available
# not available
# not available
# not available
# /home/abbylute/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
# 0.19607843137254902% done
# /home/abbylute/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_26963/634082879.py in <module>
#      62
#      63             # calculate the spatially weighted GMST
# ---> 64             zz = spatial_mean(zz)
#      65
#      66             if scen=='historical':
#
# /tmp/ipykernel_26963/3643480245.py in spatial_mean(xx)
#       5     weights.name = "weights"
#       6     xx_weighted = xx.weighted(weights)
# ----> 7     weighted_mean = xx_weighted.mean(("lon", "lat"))
#       8     return weighted_mean
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/weighted.py in mean(self, dim, skipna, keep_attrs)
#     284
#     285         return self._implementation(
# --> 286             self._weighted_mean, dim=dim, skipna=skipna, keep_attrs=keep_attrs
#     287         )
#     288
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/weighted.py in _implementation(self, func, dim, **kwargs)
#     332         self._check_dim(dim)
#     333
# --> 334         return self.obj.map(func, dim=dim, **kwargs)
#     335
#     336
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/dataset.py in map(self, func, keep_attrs, args, **kwargs)
#    5150         variables = {
#    5151             k: maybe_wrap_array(v, func(v, *args, **kwargs))
# -> 5152             for k, v in self.data_vars.items()
#    5153         }
#    5154         if keep_attrs:
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/dataset.py in <dictcomp>(.0)
#    5150         variables = {
#    5151             k: maybe_wrap_array(v, func(v, *args, **kwargs))
# -> 5152             for k, v in self.data_vars.items()
#    5153         }
#    5154         if keep_attrs:
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/weighted.py in _weighted_mean(self, da, dim, skipna)
#     210         """Reduce a DataArray by a weighted ``mean`` along some dimension(s)."""
#     211
# --> 212         weighted_sum = self._weighted_sum(da, dim=dim, skipna=skipna)
#     213
#     214         sum_of_weights = self._sum_of_weights(da, dim=dim)
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/weighted.py in _weighted_sum(self, da, dim, skipna)
#     200         """Reduce a DataArray by a weighted ``sum`` along some dimension(s)."""
#     201
# --> 202         return self._reduce(da, self.weights, dim=dim, skipna=skipna)
#     203
#     204     def _weighted_mean(
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/weighted.py in _reduce(da, weights, dim, skipna)
#     152         # need to mask invalid values in da, as `dot` does not implement skipna
#     153         if skipna or (skipna is None and da.dtype.kind in "cfO"):
# --> 154             da = da.fillna(0.0)
#     155
#     156         # `dot` does not broadcast arrays, so this avoids creating a large
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/dataarray.py in fillna(self, value)
#    2462                 "fillna on a DataArray"
#    2463             )
# -> 2464         out = ops.fillna(self, value)
#    2465         return out
#    2466
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/ops.py in fillna(data, other, join, dataset_join)
#     151         dataset_join=dataset_join,
#     152         dataset_fill_value=np.nan,
# --> 153         keep_attrs=True,
#     154     )
#     155
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/computation.py in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, *args)
#    1169             join=join,
#    1170             exclude_dims=exclude_dims,
# -> 1171             keep_attrs=keep_attrs,
#    1172         )
#    1173     # feed Variables directly through apply_variable_ufunc
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/computation.py in apply_dataarray_vfunc(func, signature, join, exclude_dims, keep_attrs, *args)
#     288
#     289     data_vars = [getattr(a, "variable", a) for a in args]
# --> 290     result_var = func(*data_vars)
#     291
#     292     if signature.num_outputs > 1:
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/computation.py in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     647         if isinstance(arg, Variable)
#     648         else arg
# --> 649         for arg, core_dims in zip(args, signature.input_core_dims)
#     650     ]
#     651
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/computation.py in <listcomp>(.0)
#     647         if isinstance(arg, Variable)
#     648         else arg
# --> 649         for arg, core_dims in zip(args, signature.input_core_dims)
#     650     ]
#     651
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/computation.py in broadcast_compat_data(variable, broadcast_dims, core_dims)
#     559     core_dims: Tuple[Hashable, ...],
#     560 ) -> Any:
# --> 561     data = variable.data
#     562
#     563     old_dims = variable.dims
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/variable.py in data(self)
#     344             return self._data
#     345         else:
# --> 346             return self.values
#     347
#     348     @data.setter
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/variable.py in values(self)
#     517     def values(self):
#     518         """The variable's data as a numpy.ndarray"""
# --> 519         return _as_array_or_item(self._data)
#     520
#     521     @values.setter
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/variable.py in _as_array_or_item(data)
#     257     TODO: remove this (replace with np.asarray) once these issues are fixed
#     258     """
# --> 259     data = np.asarray(data)
#     260     if data.ndim == 0:
#     261         if data.dtype.kind == "M":
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     549
#     550     def __array__(self, dtype=None):
# --> 551         self._ensure_cached()
#     552         return np.asarray(self.array, dtype=dtype)
#     553
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/indexing.py in _ensure_cached(self)
#     546     def _ensure_cached(self):
#     547         if not isinstance(self.array, NumpyIndexingAdapter):
# --> 548             self.array = NumpyIndexingAdapter(np.asarray(self.array))
#     549
#     550     def __array__(self, dtype=None):
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     519
#     520     def __array__(self, dtype=None):
# --> 521         return np.asarray(self.array, dtype=dtype)
#     522
#     523     def __getitem__(self, key):
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     420     def __array__(self, dtype=None):
#     421         array = as_indexable(self.array)
# --> 422         return np.asarray(array[self.key], dtype=None)
#     423
#     424     def transpose(self, order):
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      68
#      69     def __array__(self, dtype=None):
# ---> 70         return self.func(self.array)
#      71
#      72     def __repr__(self):
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/coding/variables.py in _apply_mask(data, encoded_fill_values, decoded_fill_value, dtype)
#     135 ) -> np.ndarray:
#     136     """Mask all matching values in a NumPy arrays."""
# --> 137     data = np.asarray(data, dtype=dtype)
#     138     condition = False
#     139     for fv in encoded_fill_values:
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     420     def __array__(self, dtype=None):
#     421         array = as_indexable(self.array)
# --> 422         return np.asarray(array[self.key], dtype=None)
#     423
#     424     def transpose(self, order):
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/xarray/backends/zarr.py in __getitem__(self, key)
#      78         else:
#      79             assert isinstance(key, indexing.OuterIndexer)
# ---> 80             return array.oindex[key.tuple]
#      81         # if self.ndim == 0:
#      82         # could possibly have a work-around for 0d data here
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/zarr/indexing.py in __getitem__(self, selection)
#     667         selection = ensure_tuple(selection)
#     668         selection = replace_lists(selection)
# --> 669         return self.array.get_orthogonal_selection(selection, fields=fields)
#     670
#     671     def __setitem__(self, selection, value):
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/zarr/core.py in get_orthogonal_selection(self, selection, out, fields)
#    1085         indexer = OrthogonalIndexer(selection, self)
#    1086
# -> 1087         return self._get_selection(indexer=indexer, out=out, fields=fields)
#    1088
#    1089     def get_coordinate_selection(self, selection, out=None, fields=None):
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/zarr/core.py in _get_selection(self, indexer, out, fields)
#    1266                 # load chunk selection into output array
#    1267                 self._chunk_getitem(chunk_coords, chunk_selection, out, out_selection,
# -> 1268                                     drop_axes=indexer.drop_axes, fields=fields)
#    1269         else:
#    1270             # allow storage to get multiple items at once
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/zarr/core.py in _chunk_getitem(self, chunk_coords, chunk_selection, out, out_selection, drop_axes, fields)
#    1977         else:
#    1978             self._process_chunk(out, cdata, chunk_selection, drop_axes,
# -> 1979                                 out_is_ndarray, fields, out_selection)
#    1980
#    1981     def _chunk_getitems(self, lchunk_coords, lchunk_selection, out, lout_selection,
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/zarr/core.py in _process_chunk(self, out, cdata, chunk_selection, drop_axes, out_is_ndarray, fields, out_selection, partial_read_decode)
#    1919         except ArrayIndexError:
#    1920             cdata = cdata.read_full()
# -> 1921         chunk = self._decode_chunk(cdata)
#    1922
#    1923         # select data from chunk
#
# ~/miniconda3/envs/warming_levels-env/lib/python3.7/site-packages/zarr/core.py in _decode_chunk(self, cdata, start, nitems, expected_shape)
#    2183                 chunk = self._compressor.decode_partial(cdata, start, nitems)
#    2184             else:
# -> 2185                 chunk = self._compressor.decode(cdata)
#    2186         else:
#    2187             chunk = cdata
#
# KeyboardInterrupt:

# %%
outdf
# Out:
#          model     member    scenario  year        GMST         1850-1900
# 0     GFDL-CM4   r1i1p1f1  historical  1850  285.901631  285.915908201504
# 1     GFDL-CM4   r1i1p1f1  historical  1851  286.032717  285.915908201504
# 2     GFDL-CM4   r1i1p1f1  historical  1852  286.029380  285.915908201504
# 3     GFDL-CM4   r1i1p1f1  historical  1853  286.068782  285.915908201504
# 4     GFDL-CM4   r1i1p1f1  historical  1854  286.109054  285.915908201504
# ..         ...        ...         ...   ...         ...               ...
# 31  NorESM2-LM  r10i1p1f2      ssp245  2046  289.010323               NaN
# 32  NorESM2-LM  r10i1p1f2      ssp245  2047  288.895761               NaN
# 33  NorESM2-LM  r10i1p1f2      ssp245  2048  289.052433               NaN
# 34  NorESM2-LM  r10i1p1f2      ssp245  2049  289.021657               NaN
# 35  NorESM2-LM  r10i1p1f2      ssp245  2050  289.012184               NaN
#
# [210429 rows x 6 columns]

# %%
# There are some model/member combinations where the historical run wasn't available, so 1850-1900=NaN. remove these
outdf.isna().sum() #35378 cases
outdf = outdf.loc[outdf['1850-1900'] > 0]
outdf
# Out:
#          model    member    scenario  year        GMST          1850-1900
# 0     GFDL-CM4  r1i1p1f1  historical  1850  285.901631   285.915908201504
# 1     GFDL-CM4  r1i1p1f1  historical  1851  286.032717   285.915908201504
# 2     GFDL-CM4  r1i1p1f1  historical  1852  286.029380   285.915908201504
# 3     GFDL-CM4  r1i1p1f1  historical  1853  286.068782   285.915908201504
# 4     GFDL-CM4  r1i1p1f1  historical  1854  286.109054   285.915908201504
# ..         ...       ...         ...   ...         ...                ...
# 81  ACCESS-CM2  r5i1p1f1      ssp585  2096  293.205425  287.0825326867011
# 82  ACCESS-CM2  r5i1p1f1      ssp585  2097  293.183995  287.0825326867011
# 83  ACCESS-CM2  r5i1p1f1      ssp585  2098  293.384004  287.0825326867011
# 84  ACCESS-CM2  r5i1p1f1      ssp585  2099  293.557349  287.0825326867011
# 85  ACCESS-CM2  r5i1p1f1      ssp585  2100  293.402363  287.0825326867011
#
# [176062 rows x 6 columns]

# %%
outfile
# Out:
# '/home/abbylute/alute_bucket/warming_levels/data/gmst_tables/CMIP6_GMST_table_all.csv'

# %%
# save the GMST table

outdf.to_csv(outfile, index=False)
